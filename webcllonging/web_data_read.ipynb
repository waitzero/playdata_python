# %% [markdown]
# # 외부 데이터 처리

# %% [markdown]
# 1. 공공데이터나 오픈된 데이터를 파일로 다운 받아서 사용(csv, 엑셀, xml, json...)
# 2. 웹 페이지를 읽어서 데이터 분석(그 웹 페이지 구조를 분석해야함)

# %%
# !pip install requests
import requests
#requests.get(url):get방식 요청 
#requests.post(url):post방식 요청 

html = requests.get('https://google.com').text  #웹 요청
html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="-uSSBltXWaC5Ef2k5ZrphA">(function(){window.google={kEI:\'rmQ-Y7D0O_W00PEP-tqQgAI\',kEXPI:\'0,18167,184368,1100001,56872,6059,207,4804,2316,383,246,5,5367,1123753,1197714,303248,77529,16114,28684,22431,1361,12312,17587,4998,13228,3847,10622,22741,5081,885,708,1279,2742,149,1103,840,1983,4314,108,3406,606,2024,1776,520,14670,3227,2845,7,5599,28171,1851,2614,12710,432,3,1590,1,5444,149,11323,2652,4,1528,2304,7039,22023,5708,7357,11442,2216,2980,1457,15351,1435,5815,2542,4094,4052,3,3541,1,42157,2,14019,2373,342,11401,9865,1758,5679,1020,2381,14023,14719,4568,6255,23422,1248,5838,14968,4332,2204,2812,2468,445,2,2,1,17306,9326,8155,6682,639,60,2,3,14284,1681,872,9626,5212,4796,7,1922,9779,21779,9543,1741,3091,1520,4242,5880,4116,206,1051,123,700,4,1,2,2,2,2,1440,6789,5688,1206,3927,1418,43,5930,1354,994,14,82,950,1902,1038,751,201,1867,125,3160,1654,2618,51,2197,488,922,862,1074,455,112,252,464,2,521,162,899,2698,59,166,338,3,1,2,1,390,424,83,12,95,459,931,106,496,366,210,597,166,885,1152,1,1100,964,1,950,523,298,2,463,45,778,79,887,1,511,195,1,371,466,881,103,66,659,18,290,28,232,449,745,979,463,1113,401,106,246,763,26,26,153,436,2,26,198,300,1242,42,423,30,99,229,472,284,29,2605,1182,5332318,76,54,5995795,2803400,3311,141,795,19735,1,1,346,1813,17,7,3,1,3,4,16,20,3,7451737,11439943,5056918,2770167,1271975,1964,3094,13579,3405,5540,3177,2601,1356852,17171\',kBL:\'5-Va\'};google.sn=\'webhp\';google.kHL=\'en\';})();(function(){\nvar f=this||self;var h,k=[];function l(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||h}function m(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}\nfunction n(a,b,c,d,g){var e="";c||-1!==b.search("&ei=")||(e="&ei="+l(d),-1===b.search("&lei=")&&(d=m(d))&&(e+="&lei="+d));d="";!c&&f._cshid&&-1===b.search("&cshid=")&&"slh"!==a&&(d="&cshid="+f._cshid);c=c||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e+"&zx="+Date.now()+d;/^http:/i.test(c)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:c,glmm:1}),c="");return c};h=google.kEI;google.getEI=l;google.getLEI=m;google.ml=function(){return null};google.log=function(a,b,c,d,g){if(c=n(a,b,c,d,g)){a=new Image;var e=k.length;k[e]=a;a.onerror=a.onload=a.onabort=function(){delete k[e]};a.src=c}};google.logUrl=n;}).call(this);(function(){\ngoogle.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;po ...

# %%
#!pip install beautifulsoup4
from bs4 import BeautifulSoup

# %%
content = BeautifulSoup(html, 'html.parser')  #html소스를 돔 객체화 
title = content.html.head.title    #소스에서 title 태그 추출
print(title.string)  #string:태그의 텍스트 값 <태그>텍스트</태그>
# Out:
# Google

# %% [markdown]
# 태그 접근 방법
# 1. root.html.body.h1 : 태그 한개 검색
# 2. root.find(태그[속성]): 태그 1개 검색. 검색이 여러개 되도 처음것 하나만 반환
# 3. root.find_all(태그[속성]): 태그 모두 검색
# 4. root.select(태그): 태그 모두 검색

# %%
#link = content.html.body.a  #처음 a 태그 하나만 추출
links = content.find_all('a')
links
# Out:
# [<a class="gb1" href="https://www.google.co.kr/imghp?hl=ko&amp;tab=wi">이미지</a>,
#  <a class="gb1" href="https://maps.google.co.kr/maps?hl=ko&amp;tab=wl">지도</a>,
#  <a class="gb1" href="https://play.google.com/?hl=ko&amp;tab=w8">Play</a>,
#  <a class="gb1" href="https://www.youtube.com/?gl=KR&amp;tab=w1">YouTube</a>,
#  <a class="gb1" href="https://news.google.com/?tab=wn">뉴스</a>,
#  <a class="gb1" href="https://mail.google.com/mail/?tab=wm">Gmail</a>,
#  <a class="gb1" href="https://drive.google.com/?tab=wo">드라이브</a>,
#  <a class="gb1" href="https://www.google.co.kr/intl/ko/about/products?tab=wh" style="text-decoration:none"><u>더보기</u> »</a>,
#  <a class="gb4" href="http://www.google.co.kr/history/optout?hl=ko">웹 기록</a>,
#  <a class="gb4" href="/preferences?hl=ko">설정</a>,
#  <a class="gb4" href="https://accounts.google.com/ServiceLogin?hl=ko&amp;passive=true&amp;continue=https://www.google.com/&amp;ec=GAZAAQ" id="gb_70" target="_top">로그인</a>,
#  <a href="/advanced_search?hl=ko&amp;authuser=0">고급검색</a>,
#  <a href="/intl/ko/ads/">광고 프로그램</a>,
#  <a href="http://www.google.co.kr/intl/ko/services/">비즈니스 솔루션</a>,
#  <a href="/intl/ko/about.html">Google 정보</a>,
#  <a href="https://www.google.com/setprefdomain?prefdom=KR&amp;prev=https://www.google.co.kr/&amp;sig=K_n2OHT9YazDJHoxlkOrIoz9bBAGs%3D">Google.co.kr</a>,
#  <a href="/intl/ko/policies/privacy/">개인정보처리방침</a>,
#  <a href="/intl/ko/policies/terms/">약관</a>]

# %%
for i in links:
    #get_text(): 요소의 텍스트 추출
    #i['href']: 속성값 읽기
    print(i.get_text(), ':', i['href'])
# Out:
# 이미지 : https://www.google.co.kr/imghp?hl=ko&tab=wi
# 지도 : https://maps.google.co.kr/maps?hl=ko&tab=wl
# Play : https://play.google.com/?hl=ko&tab=w8
# YouTube : https://www.youtube.com/?gl=KR&tab=w1
# 뉴스 : https://news.google.com/?tab=wn
# Gmail : https://mail.google.com/mail/?tab=wm
# 드라이브 : https://drive.google.com/?tab=wo
# 더보기 » : https://www.google.co.kr/intl/ko/about/products?tab=wh
# 웹 기록 : http://www.google.co.kr/history/optout?hl=ko
# 설정 : /preferences?hl=ko
# 로그인 : https://accounts.google.com/ServiceLogin?hl=ko&passive=true&continue=https://www.google.com/&ec=GAZAAQ
# 고급검색 : /advanced_search?hl=ko&authuser=0
# 광고 프로그램 : /intl/ko/ads/
# 비즈니스 솔루션 : http://www.google.co.kr/intl/ko/services/
# Google 정보 : /intl/ko/about.html
# Google.co.kr : https://www.google.com/setprefdomain?prefdom=KR&prev=https://www.google.co.kr/&sig=K_2QTXjmi4ROkFkO2kPbc0I025oos%3D
# 개인정보처리방침 : /intl/ko/policies/privacy/
# 약관 : /intl/ko/policies/terms/

# %%
html = '<html>'
html += '<body>'
html += '<p class=a>aaa</p>'
html += '<p class=b>bbb</p>'
html += '<p class=a>ccc</p>'
html += '<p class=a id=xxx>ddd</p>'
html += '</body>'
html += '</html>'

root = BeautifulSoup(html, 'html.parser') 
p1 = root.find_all('p')
print('p1:', p1)
p2 = root.find_all('p', {'class':'a'})
print('p2:', p2)
p3 = root.find_all('p', {'class':'b'})
print('p3:', p3)
p4 = root.find('p', {'class':'a', 'id':'xxx'})
print('p4:', p4)
p5 = root.select('p')
print('p5:', p5)
p6 = root.select('p.a')#태그.클래스명 //태그#id명
print('p6:', p6)
p7 = root.select('p.b')
print('p7:', p7)
p8 = root.select('p#xxx')
print('p8:', p8)
# Out:
# p1: [<p class="a">aaa</p>, <p class="b">bbb</p>, <p class="a">ccc</p>, <p class="a" id="xxx">ddd</p>]
# p2: [<p class="a">aaa</p>, <p class="a">ccc</p>, <p class="a" id="xxx">ddd</p>]
# p3: [<p class="b">bbb</p>]
# p4: <p class="a" id="xxx">ddd</p>
# p5: [<p class="a">aaa</p>, <p class="b">bbb</p>, <p class="a">ccc</p>, <p class="a" id="xxx">ddd</p>]
# p6: [<p class="a">aaa</p>, <p class="a">ccc</p>, <p class="a" id="xxx">ddd</p>]
# p7: [<p class="b">bbb</p>]
# p8: [<p class="a" id="xxx">ddd</p>]

# %%
url = 'https://ent.sbs.co.kr/news/flash.do?plink=GNB&cooper=SBSENTERNEWS'
html = requests.get(url).text  
root = BeautifulSoup(html, 'html.parser') 
divs = root.select('div.w_nwl_text')#기사 div 태그들만 추출
divs
# Out:
# [<div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[빅픽처] '위대한 배우' 양조위의 화양연화</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">'화양연화'. 영 제목으로도 익히 알려진 이 말은 '인생에서 가장 아름답고 행복한 시간'이라는 의미를 품고 있다. 차우의 이루어질 수 없는 사랑을 그리는 동시에 중국 반환 전 찬란했던 홍콩을 추억하는 영화기도 한 '화양연화'는 한국 씨네필에게도 열렬한 지지를 받았던 왕가위 영화 미학의 정점을 보여준 작품이다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">김지혜 </em>
#  <div class="nwl_subtext">2022.10.06 14:11</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">'골칫덩이 생선' 배스가 맛있다니…'공생2' 이연복X정호영, 요리 빅매치</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">'공생의 법칙2'에서 스타 셰프들이 배스를 이용한 요리법을 소개한다. 6일 방송될 SBS '공생의 법칙2'에서는 침입 외래종에 대한 다양한 대처법을 체험하고 돌아온 김병만, 배정남, 박군이 '배스 낚시의 성지'로 불리는 안동호에서 '공생 ESG 페스티벌'을 개최하는 모습이 그려진다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">강선애 </em>
#  <div class="nwl_subtext">2022.10.06 13:59</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] 양조위가 할리우드 데뷔작으로 마블 영화를 고른 이유</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 양조위와 마블의 만남은 전혀 생각지 못한 조합이었다. 2021년 '샹치와 텐 링즈의 전설'의 개봉을 앞두고 그의 팬들이 공통적으로 했던 생각이었다. 그도 그럴 것이 양조위는 청춘스타로 이름을 날렸던 20~30대 이후 연기 스펙트럼을 넓혀가며 작가주의 감독에 잇따라 출연했다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">김지혜 </em>
#  <div class="nwl_subtext">2022.10.06 12:26</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] '아시아영화인상' 양조위 "연쇄살인마 역 도전해보고 싶어"</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 양조위가 연쇄살인마 역할에 도전해보고 싶다고 밝혔다. 6일 오전 11시 부산 해운대구 우동 KNN센터 KNN시어터에서 열린 올해의 아시아영화인상 기자회견에 참석한 양조위는 악역에 대한 관심을 드러냈다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">김지혜 </em>
#  <div class="nwl_subtext">2022.10.06 12:01</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] 양조위, '월드 스타도 사랑하는 K하트'</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석해 포토타임을 갖고 있다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">백승철 </em>
#  <div class="nwl_subtext">2022.10.06 11:59</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] 양조위, '명품 배우의 미소'</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석해 질의응답 시간을 갖고 있다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">백승철 </em>
#  <div class="nwl_subtext">2022.10.06 11:43</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] 허문영 집행위원장, '대배우 양조위를 소개합니다'</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">허문영 집행위원장과 배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 기자회견에 참석하고 있다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">백승철 </em>
#  <div class="nwl_subtext">2022.10.06 11:33</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">라미란 "'코미디 퀸' 수식어 부담…다양한 모습으로 연기 계속하고파"</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 라미란이 자신의 수식어 '코미디 퀸'에 대해 솔직한 심정을 밝혔습니다. 어제 씨제스 엔터테인먼트는 영화 '컴백홈' 개봉일에 맞춰 라미란의 인터뷰를 공개했습니다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">전민재 </em>
#  <div class="nwl_subtext">2022.10.06 11:32</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] 양조위, '수많은 취재진 질문에 경청'</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석해 질의응답 시간을 갖고 있다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">백승철 </em>
#  <div class="nwl_subtext">2022.10.06 11:31</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] 양조위, '부산 사로잡은 인자한 미소'</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석하고 있다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">백승철 </em>
#  <div class="nwl_subtext">2022.10.06 11:29</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] '아시아영화인상' 양조위가 밝힌 눈빛 연기의 비결 "오랜 관찰과 준비"</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 양조위가 특유의 깊은 눈빛 연기의 비결로 오랜 관찰과 준비를 꼽았다. 6일 오전 11시 부산 해운대구 우동 KNN센터 KNN시어터에서 열린 올해의 아시아영화인상 기자회견에 참석한 양조위는 개막식에서 뜻깊은 수상을 한 것과 관련해 "상을 받게 돼 영광"이라고 짧게 소감을 전했다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">김지혜 </em>
#  <div class="nwl_subtext">2022.10.06 11:28</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] 양조위, '내 자리가 맞나'</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석하고 있다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">백승철 </em>
#  <div class="nwl_subtext">2022.10.06 11:28</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] 양조위, '올해의 아시아영화인상 수상'</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석하고 있다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">백승철 </em>
#  <div class="nwl_subtext">2022.10.06 11:27</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">[27th BIFF] 양조위, '부산 찾은 월드 스타'</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석하고 있다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">백승철 </em>
#  <div class="nwl_subtext">2022.10.06 11:24</div>
#  </div>
#  </div>, <div class="w_nwl_text">
#  <!-- 기사 타이틀 -->
#  <h3 class="nwl_title">"천백사, 제대로 터졌다"…'천변' 남궁민X김지은X박진우 팀 케미 '호평'</h3>
#  <!-- 기사 리드문 -->
#  <div class="nwl_text">'천원짜리 변호사' 남궁민-김지은-박진우의 '원팀' 케미가 드라마의 재미를 더하고 있는 가운데, 화기애애한 현장 분위기를 엿볼 수 있는 비하인드 스틸이 공개됐다.</div>
#  <!-- 기사 정보 (기자 및 날짜시간) -->
#  <div class="w_nwl_info">
#  <em class="nwl_reporter">강선애 </em>
#  <div class="nwl_subtext">2022.10.06 11:23</div>
#  </div>
#  </div>]

# %%
for i in divs:
    title = i.find('h3').text
    print('title:', title)
    #select는 여러개검색하는 함수이므로 반환타입이 []리스트다
    text = i.select('div.nwl_text')[0].text  
    print('text:', text)
    writer = i.select('em.nwl_reporter')[0].text
    print('writer:', writer)
    time = i.select('div.nwl_subtext')[0].text
    print('time:', time)
    print('====================')
# Out:
# title: [빅픽처] '위대한 배우' 양조위의 화양연화
# text: '화양연화'. 영 제목으로도 익히 알려진 이 말은 '인생에서 가장 아름답고 행복한 시간'이라는 의미를 품고 있다. 차우의 이루어질 수 없는 사랑을 그리는 동시에 중국 반환 전 찬란했던 홍콩을 추억하는 영화기도 한 '화양연화'는 한국 씨네필에게도 열렬한 지지를 받았던 왕가위 영화 미학의 정점을 보여준 작품이다.
# writer: 김지혜
# time: 2022.10.06 14:11
# ====================
# title: '골칫덩이 생선' 배스가 맛있다니…'공생2' 이연복X정호영, 요리 빅매치
# text: '공생의 법칙2'에서 스타 셰프들이 배스를 이용한 요리법을 소개한다. 6일 방송될 SBS '공생의 법칙2'에서는 침입 외래종에 대한 다양한 대처법을 체험하고 돌아온 김병만, 배정남, 박군이 '배스 낚시의 성지'로 불리는 안동호에서 '공생 ESG 페스티벌'을 개최하는 모습이 그려진다.
# writer: 강선애
# time: 2022.10.06 13:59
# ====================
# title: [27th BIFF] 양조위가 할리우드 데뷔작으로 마블 영화를 고른 이유
# text: 배우 양조위와 마블의 만남은 전혀 생각지 못한 조합이었다. 2021년 '샹치와 텐 링즈의 전설'의 개봉을 앞두고 그의 팬들이 공통적으로 했던 생각이었다. 그도 그럴 것이 양조위는 청춘스타로 이름을 날렸던 20~30대 이후 연기 스펙트럼을 넓혀가며 작가주의 감독에 잇따라 출연했다.
# writer: 김지혜
# time: 2022.10.06 12:26
# ====================
# title: [27th BIFF] '아시아영화인상' 양조위 "연쇄살인마 역 도전해보고 싶어"
# text: 배우 양조위가 연쇄살인마 역할에 도전해보고 싶다고 밝혔다. 6일 오전 11시 부산 해운대구 우동 KNN센터 KNN시어터에서 열린 올해의 아시아영화인상 기자회견에 참석한 양조위는 악역에 대한 관심을 드러냈다.
# writer: 김지혜
# time: 2022.10.06 12:01
# ====================
# title: [27th BIFF] 양조위, '월드 스타도 사랑하는 K하트'
# text: 배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석해 포토타임을 갖고 있다.
# writer: 백승철
# time: 2022.10.06 11:59
# ====================
# title: [27th BIFF] 양조위, '명품 배우의 미소'
# text: 배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석해 질의응답 시간을 갖고 있다.
# writer: 백승철
# time: 2022.10.06 11:43
# ====================
# title: [27th BIFF] 허문영 집행위원장, '대배우 양조위를 소개합니다'
# text: 허문영 집행위원장과 배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 기자회견에 참석하고 있다.
# writer: 백승철
# time: 2022.10.06 11:33
# ====================
# title: 라미란 "'코미디 퀸' 수식어 부담…다양한 모습으로 연기 계속하고파"
# text: 배우 라미란이 자신의 수식어 '코미디 퀸'에 대해 솔직한 심정을 밝혔습니다. 어제 씨제스 엔터테인먼트는 영화 '컴백홈' 개봉일에 맞춰 라미란의 인터뷰를 공개했습니다.
# writer: 전민재
# time: 2022.10.06 11:32
# ====================
# title: [27th BIFF] 양조위, '수많은 취재진 질문에 경청'
# text: 배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석해 질의응답 시간을 갖고 있다.
# writer: 백승철
# time: 2022.10.06 11:31
# ====================
# title: [27th BIFF] 양조위, '부산 사로잡은 인자한 미소'
# text: 배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석하고 있다.
# writer: 백승철
# time: 2022.10.06 11:29
# ====================
# title: [27th BIFF] '아시아영화인상' 양조위가 밝힌 눈빛 연기의 비결 "오랜 관찰과 준비"
# text: 배우 양조위가 특유의 깊은 눈빛 연기의 비결로 오랜 관찰과 준비를 꼽았다. 6일 오전 11시 부산 해운대구 우동 KNN센터 KNN시어터에서 열린 올해의 아시아영화인상 기자회견에 참석한 양조위는 개막식에서 뜻깊은 수상을 한 것과 관련해 "상을 받게 돼 영광"이라고 짧게 소감을 전했다.
# writer: 김지혜
# time: 2022.10.06 11:28
# ====================
# title: [27th BIFF] 양조위, '내 자리가 맞나'
# text: 배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석하고 있다.
# writer: 백승철
# time: 2022.10.06 11:28
# ====================
# title: [27th BIFF] 양조위, '올해의 아시아영화인상 수상'
# text: 배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석하고 있다.
# writer: 백승철
# time: 2022.10.06 11:27
# ====================
# title: [27th BIFF] 양조위, '부산 찾은 월드 스타'
# text: 배우 양조위가 6일 오전 부산 해운대구 KNN타워 KNN시어터에서 열린 '제27회 부산국제영화제' 올해의 아시아영화인상 수상 기념 기자회견에 참석하고 있다.
# writer: 백승철
# time: 2022.10.06 11:24
# ====================
# title: "천백사, 제대로 터졌다"…'천변' 남궁민X김지은X박진우 팀 케미 '호평'
# text: '천원짜리 변호사' 남궁민-김지은-박진우의 '원팀' 케미가 드라마의 재미를 더하고 있는 가운데, 화기애애한 현장 분위기를 엿볼 수 있는 비하인드 스틸이 공개됐다.
# writer: 강선애
# time: 2022.10.06 11:23
# ====================

# %%
html = requests.get('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp').text  #웹 요청
#html=html.decode('utf-8')
#지역별 일간 날씨를 출력
root = BeautifulSoup(html, 'html.parser') 
loc = root.find_all('location')
for i in loc:  # i:<location>
    print(i.city.get_text(), '지역 날씨========')
    d = i.find_all('data')
    for j in d: # j:<data>
        print(j.tmef.string , ':', j.wf.string, ' / 최저온도:', j.tmn.string, ' / 최고온도:', j.tmx.string, ' / 습도:',j.rnst.string,'%')
# Out:
# 서울 지역 날씨========
# 2022-10-09 00:00 : 흐림  / 최저온도: 12  / 최고온도: 18  / 습도: 40 %
# 2022-10-09 12:00 : 흐리고 비  / 최저온도: 12  / 최고온도: 18  / 습도: 100 %
# 2022-10-09 00:00 : 흐림  / 최저온도: 19  / 최고온도: 23  / 습도: 40 %
# 2022-10-09 12:00 : 흐리고 비  / 최저온도: 19  / 최고온도: 23  / 습도: 80 %
# 2022-10-10 00:00 : 구름많음  / 최저온도: 16  / 최고온도: 20  / 습도: 40 %
# 2022-10-10 12:00 : 구름많음  / 최저온도: 16  / 최고온도: 20  / 습도: 30 %
# 2022-10-11 00:00 : 구름많음  / 최저온도: 15  / 최고온도: 21  / 습도: 30 %
# 2022-10-11 12:00 : 맑음  / 최저온도: 15  / 최고온도: 21  / 습도: 10 %
# 2022-10-12 00:00 : 맑음  / 최저온도: 14  / 최고온도: 23  / 습도: 0 %
# 2022-10-12 12:00 : 맑음  / 최저온도: 14  / 최고온도: 23  / 습도: 0 %
# 2022-10-13 00:00 : 구름많음  / 최저온도: 18  / 최고온도: 24  / 습도: 20 %
# 2022-10-13 12:00 : 구름많음  / 최저온도: 18  / 최고온도: 24  / 습도: 20 %
# 2022-10-14 00:00 : 구름많음  / 최저온도: 19  / 최고온도: 24  / 습도: 20 %
# 2022-10-15 00:00 : 맑음  / 최저온도: 18  / 최고온도: 24  / 습도: 20 %
# 2022-10-16 00:00 : 맑음  / 최저온도: 17  / 최고온도: 23  / 습도: 20 %

# %%
url = 'https://search.daum.net/search?w=tot&q=%EC%8B%A4%EC%8B%9C%EA%B0%84%EC%98%81%ED%99%94%EC%98%88%EB%A7%A4%EC%9C%A8&DA=MOR&rtmaxcoll=MOR'
html = requests.get(url).text  #웹 요청

root = BeautifulSoup(html, 'html.parser') 
ol = root.select('#morColl > div.coll_cont > div > ol')[0]
lis = ol.select('li')
for i in range(5):
  li = lis[i]
  src = li.select('div.wrap_thumb > a > img')[0]['src']
  title = li.select('div.wrap_cont.cont_type2 > div > a')[0].text
  score = li.select('div.wrap_cont.cont_type2 > dl.dl_comm.star_comp_s > dd.score > em')[0].text
  rate = li.select('div.wrap_cont.cont_type2 > dl:nth-child(3) > dd')[0].text
  opendt = li.select('div.wrap_cont.cont_type2 > dl:nth-child(4) > dd')[0].text
  acc_au = li.select('div.wrap_cont.cont_type2 > dl:nth-child(5) > dd')[0].text
# Out:
# src: https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fcfe6a6b2431cb364e2330f417c3866e2fad97b18
# title: 인생은 아름다워
# score: 8.9
# src: https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fec835362c051a621cda0411af5a61a20464a161b
# title: 정직한 후보2
# score: 3.3
# src: https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F36f22dea0e0a9e0e626c549ce689558160c46ed4
# title: 공조2: 인터내셔날
# score: 7.9
# src: https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fd0235b8e9c0048e4301f8c9c74da929863e33456
# title: 듄
# score: 7.0
# src: https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fa84755e53eb8e03b51d11099d1b809b419e12873
# title: 극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교
# score: 8.7

# %%
import json
j = '[{"id":"aaa", "pwd":"111"},{"id":"bbb", "pwd":"222"}]'#json 데이터

items = json.loads(j)#제이슨 파싱하여 객체화. items는 배열
for item in items:
    print(item['id'], ':', item['pwd'])
# Out:
# aaa : 111
# bbb : 222

# %%
j = '['
j += '{"info":{"id":"aaa", "pwd":"111"}, "colors":["red", "blue", "yellow"]},'
j += '{"info":{"id":"bbb", "pwd":"222"}, "colors":["red2", "blue2", "yellow2"]}'
j += ']'

items = json.loads(j)
for item in items:
    info = item['info']
    arr = item['colors']
    print(info['id'], ' / ', info['pwd'])
    for a in arr:
        print(a, end=', ')
    print()
# Out:
# aaa  /  111
# red, blue, yellow,
# bbb  /  222
# red2, blue2, yellow2,

# %%
html = requests.get('https://api.github.com/repositories').text
items = json.loads(html)#제이슨 파싱하여 객체화. items는 배열
for item in items:
    print('id:', item['id'], ' / ', 'name:', item['name'], ' / ', 'login:', item['owner']['login'])
# Out:
# id: 1  /  name: grit  /  login: mojombo
# id: 26  /  name: merb-core  /  login: wycats
# id: 27  /  name: rubinius  /  login: rubinius
# id: 28  /  name: god  /  login: mojombo
# id: 29  /  name: jsawesome  /  login: vanpelt
# id: 31  /  name: jspec  /  login: wycats
# id: 35  /  name: exception_logger  /  login: defunkt
# id: 36  /  name: ambition  /  login: defunkt
# id: 42  /  name: restful-authentication  /  login: technoweenie
# id: 43  /  name: attachment_fu  /  login: technoweenie
# id: 48  /  name: microsis  /  login: caged
# id: 52  /  name: s3  /  login: anotherjesse
# id: 53  /  name: taboo  /  login: anotherjesse
# id: 54  /  name: foxtracs  /  login: anotherjesse
# id: 56  /  name: fotomatic  /  login: anotherjesse
# id: 61  /  name: glowstick  /  login: mojombo
# id: 63  /  name: starling  /  login: defunkt
# id: 65  /  name: merb-more  /  login: wycats
# id: 68  /  name: thin  /  login: macournoyer
# id: 71  /  name: resource_controller  /  login: jamesgolick
# id: 73  /  name: markaby  /  login: jamesgolick
# id: 74  /  name: enum_field  /  login: jamesgolick
# id: 75  /  name: subtlety  /  login: defunkt
# id: 92  /  name: zippy  /  login: defunkt
# id: 93  /  name: cache_fu  /  login: defunkt
# id: 95  /  name: phosphor  /  login: KirinDave
# id: 98  /  name: sinatra  /  login: bmizerany
# id: 102  /  name: gsa-prototype  /  login: jnewland
# id: 105  /  name: duplikate  /  login: technoweenie
# id: 118  /  name: lazy_record  /  login: jnewland
# id: 119  /  name: gsa-feeds  /  login: jnewland
# id: 120  /  name: votigoto  /  login: jnewland
# id: 127  /  name: mofo  /  login: defunkt
# id: 129  /  name: xhtmlize  /  login: jnewland
# id: 130  /  name: ruby-git  /  login: ruby-git
# id: 131  /  name: bmhsearch  /  login: ezmobius
# id: 137  /  name: mofo  /  login: uggedal
# id: 139  /  name: simply_versioned  /  login: mmower
# id: 140  /  name: gchart  /  login: abhay
# id: 141  /  name: schemr  /  login: benburkert
# id: 142  /  name: calais  /  login: abhay
# id: 144  /  name: chronic  /  login: mojombo
# id: 165  /  name: git-wiki  /  login: sr
# id: 177  /  name: signal-wiki  /  login: queso
# id: 179  /  name: ruby-on-rails-tmbundle  /  login: drnic
# id: 185  /  name: low-pro-for-jquery  /  login: danwrong
# id: 186  /  name: merb-core  /  login: wayneeseguin
# id: 190  /  name: dst  /  login: sr
# id: 191  /  name: yaws  /  login: mojombo
# id: 192  /  name: yaws  /  login: KirinDave
# id: 193  /  name: tasks  /  login: sr
# id: 195  /  name: ruby-on-rails-tmbundle  /  login: mattetti
# id: 199  /  name: amazon-ec2  /  login: grempe
# id: 203  /  name: merblogger  /  login: wayneeseguin
# id: 204  /  name: merbtastic  /  login: wayneeseguin
# id: 205  /  name: alogr  /  login: wayneeseguin
# id: 206  /  name: autozest  /  login: wayneeseguin
# id: 207  /  name: rnginx  /  login: wayneeseguin
# id: 208  /  name: sequel  /  login: wayneeseguin
# id: 211  /  name: simply_versioned  /  login: bmizerany
# id: 212  /  name: switchpipe  /  login: peterc
# id: 213  /  name: arc  /  login: hornbeck
# id: 217  /  name: ebay4r  /  login: up_the_irons
# id: 218  /  name: merb-plugins  /  login: wycats
# id: 220  /  name: ram  /  login: up_the_irons
# id: 230  /  name: ambitious_activeldap  /  login: defunkt
# id: 232  /  name: fitter_happier  /  login: atmos
# id: 237  /  name: oebfare  /  login: brosner
# id: 245  /  name: credit_card_tools  /  login: up_the_irons
# id: 248  /  name: rorem  /  login: jnicklas
# id: 249  /  name: braid  /  login: cristibalan
# id: 251  /  name: uploadcolumn  /  login: jnicklas
# id: 252  /  name: ruby-on-rails-tmbundle  /  login: simonjefford
# id: 256  /  name: rack-mirror  /  login: leahneukirchen
# id: 257  /  name: coset-mirror  /  login: leahneukirchen
# id: 267  /  name: javascript-unittest-tmbundle  /  login: drnic
# id: 273  /  name: eycap  /  login: engineyard
# id: 279  /  name: gitsum  /  login: leahneukirchen
# id: 293  /  name: sequel-model  /  login: wayneeseguin
# id: 305  /  name: god  /  login: kevinclark
# id: 307  /  name: blerb-core  /  login: hornbeck
# id: 312  /  name: django-mptt  /  login: brosner
# id: 314  /  name: bus-scheme  /  login: technomancy
# id: 319  /  name: javascript-bits  /  login: caged
# id: 320  /  name: groomlake  /  login: caged
# id: 322  /  name: forgery  /  login: sevenwire
# id: 324  /  name: ambitious-sphinx  /  login: technicalpickles
# id: 329  /  name: soup  /  login: lazyatom
# id: 332  /  name: rails  /  login: josh
# id: 334  /  name: backpacking  /  login: cdcarter
# id: 339  /  name: capsize  /  login: jnewland
# id: 351  /  name: starling  /  login: bs
# id: 360  /  name: ape  /  login: sr
# id: 362  /  name: awesomeness  /  login: collectiveidea
# id: 363  /  name: audited  /  login: collectiveidea
# id: 364  /  name: acts_as_geocodable  /  login: collectiveidea
# id: 365  /  name: acts_as_money  /  login: collectiveidea
# id: 367  /  name: calendar_builder  /  login: collectiveidea
# id: 368  /  name: clear_empty_attributes  /  login: collectiveidea
# id: 369  /  name: css_naked_day  /  login: collectiveidea

# %%
import json

f = open('serviceAreaFoods.json', 'r', encoding='utf-8')
json_data = json.load(f)
food1 = json_data['http://data.ex.co.kr:80/link/serviceAreaFoods/B00099']
print('가격:', food1['http://data.ex.co.kr:80/link/def/salePrice'][0]['value'])
print('메뉴명:', food1['http://data.ex.co.kr:80/link/def/batchMenu'][0]['value'])
print('지역명:', food1['http://data.ex.co.kr:80/link/def/serviceAreaName'][0]['value'])
print('고속도로명:', food1['http://data.ex.co.kr:80/link/def/routeName'][0]['value'])
print('방향:', food1['http://data.ex.co.kr:80/link/def/direction'][0]['value'])
# Out:
# 가격: ￦7,000
# 메뉴명: 영양더덕산채비빔밥
# 지역명: 산청
# 고속도로명: 통영대전ㆍ중부고속도로
# 방향: 통영

# %%
# json 
for i in json_data: # 음식 하나씩 추출
    food_data = json_data[i]
    for j in food_data: # 음식 정보를 하나씩 추출
        ss = j.split('/')
        title = ss[len(ss)-1]
        data = food_data[j]
        print(title,':',data[0]['value'])
    print('========================')
# Out:
# salePrice : ￦7,000
# batchMenu : 영양더덕산채비빔밥
# serviceAreaName : 산청
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 영양더덕산채비빔밥
# direction : 통영
# ========================
# salePrice : ￦6,000
# batchMenu : 베이컨 김치 볶음밥
# serviceAreaName : 공주
# routeName : 당진영덕고속도로
# rdf-schema#label : 베이컨 김치 볶음밥
# direction : 상주
# ========================
# salePrice : ￦7,000
# batchMenu : 새송이 돌솥비빔밥
# serviceAreaName : 남성주
# routeName : 중부내륙고속도로
# rdf-schema#label : 새송이 돌솥비빔밥
# direction : 양평
# ========================
# salePrice : ￦7,000
# batchMenu : 제주고사리육개장
# serviceAreaName : 기흥
# routeName : 경부고속도로
# rdf-schema#label : 제주고사리육개장
# direction : 부산
# ========================
# salePrice : ￦7,000
# batchMenu : 완주한우불고기철판비빔밥
# serviceAreaName : 이서
# routeName : 호남고속도로
# rdf-schema#label : 완주한우불고기철판비빔밥
# direction : 순천
# ========================
# salePrice : ￦7,000
# batchMenu : 엄나무닭개장
# serviceAreaName : 진안마이산
# routeName : 익산포항고속도로
# rdf-schema#label : 엄나무닭개장
# direction : 익산
# ========================
# salePrice : ￦7,000
# batchMenu : 청통한우국밥
# serviceAreaName : 청통
# routeName : 익산포항고속도로
# rdf-schema#label : 청통한우국밥
# direction : 익산
# ========================
# salePrice : ￦7,000
# batchMenu : 비빔된장찌개
# serviceAreaName : 문산
# routeName : 남해고속도로
# rdf-schema#label : 비빔된장찌개
# direction : 순천
# ========================
# salePrice : ￦8,000
# batchMenu : 죽암왕갈비탕
# serviceAreaName : 죽암
# routeName : 경부고속도로
# rdf-schema#label : 죽암왕갈비탕
# direction : 부산
# ========================
# salePrice : ￦6,500
# batchMenu : 오미자 돈가스
# serviceAreaName : 문경
# routeName : 중부내륙고속도로
# rdf-schema#label : 오미자 돈가스
# direction : 양평
# ========================
# salePrice : ￦6,500
# batchMenu : 뽀글이돼지찌개정식
# serviceAreaName : 평사
# routeName : 경부고속도로
# rdf-schema#label : 뽀글이돼지찌개정식
# direction : 부산
# ========================
# salePrice : ￦5,500
# batchMenu : 콩나물국밥
# serviceAreaName : 주암
# routeName : 호남고속도로
# rdf-schema#label : 콩나물국밥
# direction : 순천
# ========================
# salePrice : ￦8,000
# batchMenu : 뚝배기 동태탕
# serviceAreaName : 신탄진
# routeName : 경부고속도로
# rdf-schema#label : 뚝배기 동태탕
# direction : 서울
# ========================
# salePrice : ￦6,000
# batchMenu : 해물짬뽕밥
# serviceAreaName : 백양사
# routeName : 호남고속도로
# rdf-schema#label : 해물짬뽕밥
# direction : 순천
# ========================
# salePrice : ￦7,000
# batchMenu : 서산어리굴젓백반
# serviceAreaName : 서산
# routeName : 서해안고속도로
# rdf-schema#label : 서산어리굴젓백반
# direction : 목포
# ========================
# salePrice : ￦7,000
# batchMenu : 충주 사과돈가스
# serviceAreaName : 충주
# routeName : 중부내륙고속도로
# rdf-schema#label : 충주 사과돈가스
# direction : 마산
# ========================
# salePrice : ￦ 6,000
# batchMenu : 우렁된장찌개
# serviceAreaName : 고성
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 우렁된장찌개
# direction : 하남
# ========================
# salePrice : ￦3,500
# batchMenu : 평양온반
# serviceAreaName : 칠곡
# routeName : 경부고속도로
# rdf-schema#label : 평양온반
# direction : 서울
# ========================
# salePrice : ￦6,000
# batchMenu : 영양돌솥비빔밥
# serviceAreaName : 진영
# routeName : 남해고속도로
# rdf-schema#label : 영양돌솥비빔밥
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 우거지사골국밥
# serviceAreaName : 음성
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 우거지사골국밥
# direction : 통영
# ========================
# salePrice : ￦7,000
# batchMenu : 한우국밥
# serviceAreaName : 안동
# routeName : 중앙고속도로
# rdf-schema#label : 한우국밥
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 알밥우동정식
# serviceAreaName : 강릉
# routeName : 영동고속도로
# rdf-schema#label : 알밥우동정식
# direction : 인천
# ========================
# salePrice : ￦7,000
# batchMenu : 대나무잎영양맑은곰탕
# serviceAreaName : 죽전
# routeName : 경부고속도로
# rdf-schema#label : 대나무잎영양맑은곰탕
# direction : 서울
# ========================
# salePrice : ￦8,000
# batchMenu : 제육돌솥비빔밥
# serviceAreaName : 부여백제
# routeName : 서천공주고속도로
# rdf-schema#label : 제육돌솥비빔밥
# direction : 서천
# ========================
# salePrice : ￦7,000
# batchMenu : 한방우(牛)불고기
# serviceAreaName : 산청
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 한방우(牛)불고기
# direction : 하남
# ========================
# salePrice : ￦7,000
# batchMenu : 돌솥굴밥
# serviceAreaName : 대천
# routeName : 서해안고속도로
# rdf-schema#label : 돌솥굴밥
# direction : 목포
# ========================
# salePrice : ￦8,000
# batchMenu : 진안인삼오리고기덮밥
# serviceAreaName : 진안마이산
# routeName : 익산포항고속도로
# rdf-schema#label : 진안인삼오리고기덮밥
# direction : 포항
# ========================
# salePrice : ￦7,000
# batchMenu : 창녕양파제육덮밥
# serviceAreaName : 영산
# routeName : 중부내륙고속도로
# rdf-schema#label : 창녕양파제육덮밥
# direction : 마산
# ========================
# salePrice : ￦6,000
# batchMenu : 해물순두부찌개
# serviceAreaName : 현풍
# routeName : 중부내륙고속도로지선
# rdf-schema#label : 해물순두부찌개
# direction : 현풍
# ========================
# salePrice : ￦6,500
# batchMenu : 낙지덮밥
# serviceAreaName : 선산
# routeName : 중부내륙고속도로
# rdf-schema#label : 낙지덮밥
# direction : 마산
# ========================
# salePrice : ￦7,000
# batchMenu : 제육덮밥
# serviceAreaName : 영천
# routeName : 익산포항고속도로
# rdf-schema#label : 제육덮밥
# direction : 익산
# ========================
# salePrice : ￦6,000
# batchMenu : 표고버섯 우렁된장찌개
# serviceAreaName : 평창
# routeName : 영동고속도로
# rdf-schema#label : 표고버섯 우렁된장찌개
# direction : 강릉
# ========================
# salePrice : ￦6,000
# batchMenu : 황태해장국
# serviceAreaName : 원주
# routeName : 중앙고속도로
# rdf-schema#label : 황태해장국
# direction : 부산
# ========================
# salePrice : ￦ 6,000
# batchMenu : 애호박찌개
# serviceAreaName : 백양사
# routeName : 호남고속도로
# rdf-schema#label : 애호박찌개
# direction : 논산
# ========================
# salePrice : ￦10,000
# batchMenu : 도리뱅뱅 정식
# serviceAreaName : 금강
# routeName : 경부고속도로
# rdf-schema#label : 도리뱅뱅 정식
# direction : 부산
# ========================
# salePrice : ￦7,000
# batchMenu : 청매실재첩비빔밥
# serviceAreaName : 섬진강
# routeName : 남해고속도로
# rdf-schema#label : 청매실재첩비빔밥
# direction : 부산
# ========================
# salePrice : ￦6,500
# batchMenu : 얼큰 새뱅이 해물순두부
# serviceAreaName : 충주
# routeName : 중부내륙고속도로
# rdf-schema#label : 얼큰 새뱅이 해물순두부
# direction : 양평
# ========================
# salePrice : ￦8,000
# batchMenu : 대추영양갈비탕
# serviceAreaName : 경산
# routeName : 경부고속도로
# rdf-schema#label : 대추영양갈비탕
# direction : 서울
# ========================
# salePrice : ￦8,000
# batchMenu : 지례흑돼지 고추장불고기
# serviceAreaName : 추풍령
# routeName : 경부고속도로
# rdf-schema#label : 지례흑돼지 고추장불고기
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 전주콩나물국밥
# serviceAreaName : 군산
# routeName : 서해안고속도로
# rdf-schema#label : 전주콩나물국밥
# direction : 시흥
# ========================
# salePrice : ￦6,000
# batchMenu : 버섯육개장
# serviceAreaName : 진영
# routeName : 남해고속도로
# rdf-schema#label : 버섯육개장
# direction : 순천
# ========================
# salePrice : ￦6,500
# batchMenu : 영양돌솥비빔밥
# serviceAreaName : 건천
# routeName : 경부고속도로
# rdf-schema#label : 영양돌솥비빔밥
# direction : 부산
# ========================
# salePrice : ￦7,000
# batchMenu : 한우국밥
# serviceAreaName : 홍성
# routeName : 서해안고속도로
# rdf-schema#label : 한우국밥
# direction : 시흥
# ========================
# salePrice : ￦7,000
# batchMenu : 매생이탕
# serviceAreaName : 서천
# routeName : 서해안고속도로
# rdf-schema#label : 매생이탕
# direction : 목포
# ========================
# salePrice : ￦7,500
# batchMenu : 오리 묵은지 치즈 가스
# serviceAreaName : 음성
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 오리 묵은지 치즈 가스
# direction : 하남
# ========================
# salePrice : ￦6,000
# batchMenu : 안성국밥
# serviceAreaName : 안성
# routeName : 경부고속도로
# rdf-schema#label : 안성국밥
# direction : 부산
# ========================
# salePrice : ￦7,000
# batchMenu : 버섯닭계장
# serviceAreaName : 부여백제
# routeName : 서천공주고속도로
# rdf-schema#label : 버섯닭계장
# direction : 공주
# ========================
# salePrice : ￦6,000
# batchMenu : 덕평소고기국밥
# serviceAreaName : 덕평
# routeName : 영동고속도로
# rdf-schema#label : 덕평소고기국밥
# direction : 인천
# ========================
# salePrice : ￦6,500
# batchMenu : 등심돈까스
# serviceAreaName : 함평나비
# routeName : 무안광주ㆍ88올림픽고속도로
# rdf-schema#label : 등심돈까스
# direction : 무안
# ========================
# salePrice : ￦6,000
# batchMenu : 순두부찌개
# serviceAreaName : 함안
# routeName : 남해고속도로
# rdf-schema#label : 순두부찌개
# direction : 순천
# ========================
# salePrice : ￦7,000
# batchMenu : 오삼불고기정식
# serviceAreaName : 오수
# routeName : 순천완주고속도로
# rdf-schema#label : 오삼불고기정식
# direction : 광양
# ========================
# salePrice : ￦7,000
# batchMenu : 한우국밥
# serviceAreaName : 선산
# routeName : 중부내륙고속도로
# rdf-schema#label : 한우국밥
# direction : 양평
# ========================
# salePrice : ￦6,000
# batchMenu : 순두부 청국장
# serviceAreaName : 화성
# routeName : 서해안고속도로
# rdf-schema#label : 순두부 청국장
# direction : 목포
# ========================
# salePrice : ￦7,000
# batchMenu : 돌솥굴밥
# serviceAreaName : 대천
# routeName : 서해안고속도로
# rdf-schema#label : 돌솥굴밥
# direction : 시흥
# ========================
# salePrice : ￦6,000
# batchMenu : 청국장
# serviceAreaName : 함양
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 청국장
# direction : 하남
# ========================
# salePrice : ￦6,000
# batchMenu : 병천 순대국밥
# serviceAreaName : 천안
# routeName : 경부고속도로
# rdf-schema#label : 병천 순대국밥
# direction : 부산
# ========================
# salePrice : ￦7,000
# batchMenu : 무진장 흑돼지 김치찌개
# serviceAreaName : 덕유산
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 무진장 흑돼지 김치찌개
# direction : 통영
# ========================
# salePrice : ￦6,000
# batchMenu : 해물순두부찌개정식
# serviceAreaName : 원주
# routeName : 중앙고속도로
# rdf-schema#label : 해물순두부찌개정식
# direction : 춘천
# ========================
# salePrice : ￦7,500
# batchMenu : 올리브 등심돈까스
# serviceAreaName : 평창
# routeName : 영동고속도로
# rdf-schema#label : 올리브 등심돈까스
# direction : 인천
# ========================
# salePrice : ￦7,000
# batchMenu : 제육덮밥
# serviceAreaName : 영천
# routeName : 익산포항고속도로
# rdf-schema#label : 제육덮밥
# direction : 포항
# ========================
# salePrice : ￦6,000
# batchMenu : 전주비빔밥
# serviceAreaName : 거창
# routeName : 무안광주ㆍ88올림픽고속도로
# rdf-schema#label : 전주비빔밥
# direction : 대구
# ========================
# salePrice : ￦6,000
# batchMenu : 시래기 돌솥밥
# serviceAreaName : 옥계
# routeName : 동해고속도로
# rdf-schema#label : 시래기 돌솥밥
# direction : 속초
# ========================
# salePrice : ￦6,000
# batchMenu : 흑돼지 김치찌개
# serviceAreaName : 장유
# routeName : 남해제2지선고속도로
# rdf-schema#label : 흑돼지 김치찌개
# direction : 냉정
# ========================
# salePrice : ￦6,000
# batchMenu : 표고버섯 우렁된장찌개
# serviceAreaName : 금왕
# routeName : 평택제천고속도로
# rdf-schema#label : 표고버섯 우렁된장찌개
# direction : 음성
# ========================
# salePrice : ￦6,000
# batchMenu : 얼큰 칼제비
# serviceAreaName : 추풍령
# routeName : 경부고속도로
# rdf-schema#label : 얼큰 칼제비
# direction : 서울
# ========================
# salePrice : ￦7,000
# batchMenu : 한우국밥
# serviceAreaName : 문막
# routeName : 영동고속도로
# rdf-schema#label : 한우국밥
# direction : 강릉
# ========================
# salePrice : ￦6,000
# batchMenu : 안성국밥
# serviceAreaName : 안성
# routeName : 경부고속도로
# rdf-schema#label : 안성국밥
# direction : 서울
# ========================
# salePrice : ￦7,000
# batchMenu : 예산사과돈가스
# serviceAreaName : 예산
# routeName : 당진영덕고속도로
# rdf-schema#label : 예산사과돈가스
# direction : 청원
# ========================
# salePrice : ￦7,000
# batchMenu : 함평한우버섯육개장
# serviceAreaName : 함평나비
# routeName : 무안광주ㆍ88올림픽고속도로
# rdf-schema#label : 함평한우버섯육개장
# direction : 대구
# ========================
# salePrice : ￦6,000
# batchMenu : 육개장
# serviceAreaName : 고성
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 육개장
# direction : 통영
# ========================
# salePrice : ￦7,000
# batchMenu : 임실 치즈 철판 비빔밥
# serviceAreaName : 오수
# routeName : 순천완주고속도로
# rdf-schema#label : 임실 치즈 철판 비빔밥
# direction : 전주
# ========================
# salePrice : ￦7,000
# batchMenu : 고창추어탕
# serviceAreaName : 고창고인돌
# routeName : 서해안고속도로
# rdf-schema#label : 고창추어탕
# direction : 시흥
# ========================
# salePrice : ￦7,000
# batchMenu : 수제돈가스
# serviceAreaName : 화성
# routeName : 서해안고속도로
# rdf-schema#label : 수제돈가스
# direction : 시흥
# ========================
# salePrice : ￦7,000
# batchMenu : 흑돼지 김치찌개
# serviceAreaName : 경주
# routeName : 경부고속도로
# rdf-schema#label : 흑돼지 김치찌개
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 닭가슴살 퓨전 포도밥
# serviceAreaName : 안성맞춤
# routeName : 평택제천고속도로
# rdf-schema#label : 닭가슴살 퓨전 포도밥
# direction : 음성
# ========================
# salePrice : ￦7,000
# batchMenu : 제육덮밥
# serviceAreaName : 남성주
# routeName : 중부내륙고속도로
# rdf-schema#label : 제육덮밥
# direction : 마산
# ========================
# salePrice : ￦6,500
# batchMenu : 돌솥비빔밥
# serviceAreaName : 죽암
# routeName : 경부고속도로
# rdf-schema#label : 돌솥비빔밥
# direction : 서울
# ========================
# salePrice : ￦6,000
# batchMenu : 개똥쑥강된장찌개
# serviceAreaName : 곡성기차마을
# routeName : 호남고속도로
# rdf-schema#label : 개똥쑥강된장찌개
# direction : 논산
# ========================
# salePrice : ￦7,000
# batchMenu : 서산어리굴젓백반
# serviceAreaName : 서산
# routeName : 서해안고속도로
# rdf-schema#label : 서산어리굴젓백반
# direction : 시흥
# ========================
# salePrice : ￦6,500
# batchMenu : 찌글이 된장찌개
# serviceAreaName : 칠곡
# routeName : 경부고속도로
# rdf-schema#label : 찌글이 된장찌개
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 된장찌개
# serviceAreaName : 구정
# routeName : 동해고속도로
# rdf-schema#label : 된장찌개
# direction : 속초
# ========================
# salePrice : ￦6,000
# batchMenu : 황태국밥
# serviceAreaName : 동해
# routeName : 동해고속도로
# rdf-schema#label : 황태국밥
# direction : 동해
# ========================
# salePrice : ￦6,000
# batchMenu : 국산콩된장뚝배기
# serviceAreaName : 군위
# routeName : 중앙고속도로
# rdf-schema#label : 국산콩된장뚝배기
# direction : 춘천
# ========================
# salePrice : ￦6,000
# batchMenu : 해물순두부
# serviceAreaName : 금왕
# routeName : 평택제천고속도로
# rdf-schema#label : 해물순두부
# direction : 평택
# ========================
# salePrice : ￦7,500
# batchMenu : 행담도 집밥
# serviceAreaName : 행담도
# routeName : 서해안고속도로
# rdf-schema#label : 행담도 집밥
# direction : 목포
# ========================
# salePrice : ￦6,000
# batchMenu : 복분자낙지연포탕
# serviceAreaName : 정읍
# routeName : 호남고속도로
# rdf-schema#label : 복분자낙지연포탕
# direction : 논산
# ========================
# salePrice : ￦7,000
# batchMenu : 한우국밥
# serviceAreaName : 문막
# routeName : 영동고속도로
# rdf-schema#label : 한우국밥
# direction : 인천
# ========================
# salePrice : ￦8,000
# batchMenu : 고창장어탕
# serviceAreaName : 고창고인돌
# routeName : 서해안고속도로
# rdf-schema#label : 고창장어탕
# direction : 목포
# ========================
# salePrice : ￦6,000
# batchMenu : 보성녹돈애호박 고추장찌개
# serviceAreaName : 보성녹차
# routeName : 남해고속도로
# rdf-schema#label : 보성녹돈애호박 고추장찌개
# direction : 순천
# ========================
# salePrice : ￦6,000
# batchMenu : 돌솥알밥
# serviceAreaName : 여산
# routeName : 호남고속도로
# rdf-schema#label : 돌솥알밥
# direction : 순천
# ========================
# salePrice : ￦6,500
# batchMenu : 수제 등심 돈가스
# serviceAreaName : 단양
# routeName : 중앙고속도로
# rdf-schema#label : 수제 등심 돈가스
# direction : 춘천
# ========================
# salePrice : ￦8,000
# batchMenu : 곤지암 소머리 국밥
# serviceAreaName : 이천
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 곤지암 소머리 국밥
# direction : 하남
# ========================
# salePrice : ￦7,000
# batchMenu : 의성마늘순살돈가스
# serviceAreaName : 군위
# routeName : 중앙고속도로
# rdf-schema#label : 의성마늘순살돈가스
# direction : 부산
# ========================
# salePrice : ￦7,000
# batchMenu : 고구마 치즈 돈가스
# serviceAreaName : 동명
# routeName : 중앙고속도로
# rdf-schema#label : 고구마 치즈 돈가스
# direction : 춘천
# ========================
# salePrice : ￦7,000
# batchMenu : 예산사과돈가스
# serviceAreaName : 예산
# routeName : 당진영덕고속도로
# rdf-schema#label : 예산사과돈가스
# direction : 상주
# ========================
# salePrice : ￦7,500
# batchMenu : 더덕 산채비빔밥
# serviceAreaName : 마장복합
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 더덕 산채비빔밥
# direction : 하남
# ========================
# salePrice : ￦7,000
# batchMenu : 해물순두부백반
# serviceAreaName : 속리산
# routeName : 당진영덕고속도로
# rdf-schema#label : 해물순두부백반
# direction : 청원
# ========================
# salePrice : ￦6,500
# batchMenu : 꼬막 비빔밥
# serviceAreaName : 진주
# routeName : 남해고속도로
# rdf-schema#label : 꼬막 비빔밥
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 대구육개장
# serviceAreaName : 현풍
# routeName : 중부내륙고속도로지선
# rdf-schema#label : 대구육개장
# direction : 대구
# ========================
# salePrice : ￦6,000
# batchMenu : 강된장보리돌솥비빔밥
# serviceAreaName : 안성맞춤
# routeName : 평택제천고속도로
# rdf-schema#label : 강된장보리돌솥비빔밥
# direction : 평택
# ========================
# salePrice : ￦6,000
# batchMenu : 된장뚝배기
# serviceAreaName : 와촌
# routeName : 익산포항고속도로
# rdf-schema#label : 된장뚝배기
# direction : 포항
# ========================
# salePrice : ￦7,000
# batchMenu : 함평한우우거지국밥
# serviceAreaName : 함평
# routeName : 서해안고속도로
# rdf-schema#label : 함평한우우거지국밥
# direction : 목포
# ========================
# salePrice : ￦7,000
# batchMenu : 명품 연근 볶음밥
# serviceAreaName : 칠서
# routeName : 중부내륙고속도로
# rdf-schema#label : 명품 연근 볶음밥
# direction : 양평
# ========================
# salePrice : ￦7,000
# batchMenu : 흑돼지 김치찌개
# serviceAreaName : 입장
# routeName : 경부고속도로
# rdf-schema#label : 흑돼지 김치찌개
# direction : 서울
# ========================
# salePrice : ￦7,500
# batchMenu : 수제돈가스
# serviceAreaName : 여주
# routeName : 영동고속도로
# rdf-schema#label : 수제돈가스
# direction : 강릉
# ========================
# salePrice : ￦6,000
# batchMenu : 영양굴국밥
# serviceAreaName : 함안
# routeName : 남해고속도로
# rdf-schema#label : 영양굴국밥
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 전주비빔밥
# serviceAreaName : 거창
# routeName : 무안광주ㆍ88올림픽고속도로
# rdf-schema#label : 전주비빔밥
# direction : 무안
# ========================
# salePrice : ￦6,000
# batchMenu : 수제순살돈가스
# serviceAreaName : 여산
# routeName : 호남고속도로
# rdf-schema#label : 수제순살돈가스
# direction : 논산
# ========================
# salePrice : ￦6,000
# batchMenu : 보성녹돈애호박 고추장찌개
# serviceAreaName : 보성녹차
# routeName : 남해고속도로
# rdf-schema#label : 보성녹돈애호박 고추장찌개
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 묵은지 김치찌개
# serviceAreaName : 순천
# routeName : 호남고속도로
# rdf-schema#label : 묵은지 김치찌개
# direction : 순천
# ========================
# salePrice : ￦7,000
# batchMenu : 무진장 흑돼지 치즈돈가스
# serviceAreaName : 덕유산
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 무진장 흑돼지 치즈돈가스
# direction : 하남
# ========================
# salePrice : ￦7,000
# batchMenu : 인삼영양가마솥비빔밥
# serviceAreaName : 인삼랜드
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 인삼영양가마솥비빔밥
# direction : 통영
# ========================
# salePrice : ￦6,000
# batchMenu : 한방닭곰탕
# serviceAreaName : 옥천
# routeName : 경부고속도로
# rdf-schema#label : 한방닭곰탕
# direction : 서울
# ========================
# salePrice : ￦7,000
# batchMenu : 안동간고등어정식
# serviceAreaName : 안동
# routeName : 중앙고속도로
# rdf-schema#label : 안동간고등어정식
# direction : 춘천
# ========================
# salePrice : ￦6,000
# batchMenu : 짜글이 된장찌개
# serviceAreaName : 동명
# routeName : 중앙고속도로
# rdf-schema#label : 짜글이 된장찌개
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 다슬기버섯된장찌개
# serviceAreaName : 황전
# routeName : 순천완주고속도로
# rdf-schema#label : 다슬기버섯된장찌개
# direction : 광양
# ========================
# salePrice : ￦7,000
# batchMenu : 한우국밥
# serviceAreaName : 홍천강
# routeName : 중앙고속도로
# rdf-schema#label : 한우국밥
# direction : 춘천
# ========================
# salePrice : ￦6,000
# batchMenu : 순두부찌개정식
# serviceAreaName : 망향
# routeName : 경부고속도로
# rdf-schema#label : 순두부찌개정식
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 한우소머리곰탕
# serviceAreaName : 통도사
# routeName : 경부고속도로
# rdf-schema#label : 한우소머리곰탕
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 마방장터국밥
# serviceAreaName : 하남(만남)
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 마방장터국밥
# direction : 통영
# ========================
# salePrice : ￦7,000
# batchMenu : 묵은지 김치찌개
# serviceAreaName : 괴산
# routeName : 중부내륙고속도로
# rdf-schema#label : 묵은지 김치찌개
# direction : 마산
# ========================
# salePrice : ￦6,500
# batchMenu : 병천순대국밥
# serviceAreaName : 천안
# routeName : 경부고속도로
# rdf-schema#label : 병천순대국밥
# direction : 서울
# ========================
# salePrice : ￦4,500
# batchMenu : 여주쌀 잔치국수
# serviceAreaName : 여주
# routeName : 영동고속도로
# rdf-schema#label : 여주쌀 잔치국수
# direction : 인천
# ========================
# salePrice : ￦7,000
# batchMenu : 새싹삼(돌솥)힐링비빔밥
# serviceAreaName : 사천
# routeName : 남해고속도로
# rdf-schema#label : 새싹삼(돌솥)힐링비빔밥
# direction : 부산
# ========================
# salePrice : ￦7,000
# batchMenu : 지리산흑돼지불고기
# serviceAreaName : 지리산
# routeName : 무안광주ㆍ88올림픽고속도로
# rdf-schema#label : 지리산흑돼지불고기
# direction : 대구
# ========================
# salePrice : ￦6,500
# batchMenu : 함평천지한우국밥
# serviceAreaName : 함평
# routeName : 서해안고속도로
# rdf-schema#label : 함평천지한우국밥
# direction : 시흥
# ========================
# salePrice : ￦8,000
# batchMenu : 한우소머리국밥
# serviceAreaName : 김천
# routeName : 경부고속도로
# rdf-schema#label : 한우소머리국밥
# direction : 서울
# ========================
# salePrice : ￦6,000
# batchMenu : 재첩국
# serviceAreaName : 섬진강
# routeName : 남해고속도로
# rdf-schema#label : 재첩국
# direction : 순천
# ========================
# salePrice : ￦7,000
# batchMenu : 백연밥상
# serviceAreaName : 함양
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 백연밥상
# direction : 통영
# ========================
# salePrice : ￦7,000
# batchMenu : 묵은지 고등어조림
# serviceAreaName : 황간
# routeName : 경부고속도로
# rdf-schema#label : 묵은지 고등어조림
# direction : 서울
# ========================
# salePrice : ￦6,500
# batchMenu : 인삼신촌설렁탕
# serviceAreaName : 인삼랜드
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 인삼신촌설렁탕
# direction : 하남
# ========================
# salePrice : ￦6,000
# batchMenu : 흑돼지김치찌개
# serviceAreaName : 곡성기차마을
# routeName : 호남고속도로
# rdf-schema#label : 흑돼지김치찌개
# direction : 순천
# ========================
# salePrice : ￦6,000
# batchMenu : 말죽거리소고기국밥
# serviceAreaName : 서울만
# routeName : 경부고속도로
# rdf-schema#label : 말죽거리소고기국밥
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 버섯육개장
# serviceAreaName : 벌곡
# routeName : 호남고속도로지선
# rdf-schema#label : 버섯육개장
# direction : 논산
# ========================
# salePrice : ￦9,000
# batchMenu : 불고기백반정식
# serviceAreaName : 황전
# routeName : 순천완주고속도로
# rdf-schema#label : 불고기백반정식
# direction : 전주
# ========================
# salePrice : ￦7,000
# batchMenu : 곤드레열무돌솥비빔밥
# serviceAreaName : 강릉
# routeName : 영동고속도로
# rdf-schema#label : 곤드레열무돌솥비빔밥
# direction : 강릉
# ========================
# salePrice : ￦7,000
# batchMenu : 한우국밥
# serviceAreaName : 홍성
# routeName : 서해안고속도로
# rdf-schema#label : 한우국밥
# direction : 목포
# ========================
# salePrice : ￦7,000
# batchMenu : 불고기 모듬버섯전골
# serviceAreaName : 건천
# routeName : 경부고속도로
# rdf-schema#label : 불고기 모듬버섯전골
# direction : 서울
# ========================
# salePrice : ￦7,000
# batchMenu : 소고기 돌솥비빔밥
# serviceAreaName : 치악
# routeName : 중앙고속도로
# rdf-schema#label : 소고기 돌솥비빔밥
# direction : 부산
# ========================
# salePrice : ￦6,500
# batchMenu : 장터국밥
# serviceAreaName : 서천
# routeName : 서해안고속도로
# rdf-schema#label : 장터국밥
# direction : 시흥
# ========================
# salePrice : ￦6,500
# batchMenu : 영양돌솥비빔밥
# serviceAreaName : 용인
# routeName : 영동고속도로
# rdf-schema#label : 영양돌솥비빔밥
# direction : 인천
# ========================
# salePrice : ￦7,000
# batchMenu : 울외비빔밥
# serviceAreaName : 군산
# routeName : 서해안고속도로
# rdf-schema#label : 울외비빔밥
# direction : 목포
# ========================
# salePrice : ￦8,000
# batchMenu : 버섯 닭갈비 정식
# serviceAreaName : 춘천
# routeName : 중앙고속도로
# rdf-schema#label : 버섯 닭갈비 정식
# direction : 부산
# ========================
# salePrice : ￦8,500
# batchMenu : 샐러드 돈까스
# serviceAreaName : 괴산
# routeName : 중부내륙고속도로
# rdf-schema#label : 샐러드 돈까스
# direction : 양평
# ========================
# salePrice : ￦10,000
# batchMenu : 한우 떡더덕스테이크
# serviceAreaName : 횡성
# routeName : 영동고속도로
# rdf-schema#label : 한우 떡더덕스테이크
# direction : 강릉
# ========================
# salePrice : ￦7,000
# batchMenu : 뚝배기 닭갈비덮밥
# serviceAreaName : 오창
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 뚝배기 닭갈비덮밥
# direction : 하남
# ========================
# salePrice : ￦7,000
# batchMenu : 돌솥된장비빔밥
# serviceAreaName : 용인
# routeName : 영동고속도로
# rdf-schema#label : 돌솥된장비빔밥
# direction : 강릉
# ========================
# salePrice : ￦4,000
# batchMenu : 사골 육개장
# serviceAreaName : 언양
# routeName : 경부고속도로
# rdf-schema#label : 사골 육개장
# direction : 서울
# ========================
# salePrice : ￦7,000
# batchMenu : 순두부 청국장
# serviceAreaName : 옥산
# routeName : 경부고속도로
# rdf-schema#label : 순두부 청국장
# direction : 부산
# ========================
# salePrice : ￦6,500
# batchMenu : 완주한우국밥
# serviceAreaName : 이서
# routeName : 호남고속도로
# rdf-schema#label : 완주한우국밥
# direction : 논산
# ========================
# salePrice : ￦8,000
# batchMenu : 산외한우뚝배기불고기
# serviceAreaName : 정읍
# routeName : 호남고속도로
# rdf-schema#label : 산외한우뚝배기불고기
# direction : 순천
# ========================
# salePrice : ￦7,000
# batchMenu : 지리산수제마늘돈가스
# serviceAreaName : 지리산
# routeName : 무안광주ㆍ88올림픽고속도로
# rdf-schema#label : 지리산수제마늘돈가스
# direction : 무안
# ========================
# salePrice : ￦7,000
# batchMenu : 매운낙지정식
# serviceAreaName : 청원
# routeName : 경부고속도로
# rdf-schema#label : 매운낙지정식
# direction : 서울
# ========================
# salePrice : ￦7,000
# batchMenu : 섬진강재첩국
# serviceAreaName : 사천
# routeName : 남해고속도로
# rdf-schema#label : 섬진강재첩국
# direction : 순천
# ========================
# salePrice : ￦10,000
# batchMenu : 갈치조림 정식
# serviceAreaName : 황간
# routeName : 경부고속도로
# rdf-schema#label : 갈치조림 정식
# direction : 부산
# ========================
# salePrice : ￦7,000
# batchMenu : 능이버섯국밥
# serviceAreaName : 화서
# routeName : 당진영덕고속도로
# rdf-schema#label : 능이버섯국밥
# direction : 상주
# ========================
# salePrice : ￦6,500
# batchMenu : 꼬막돌솥비빔밥
# serviceAreaName : 주암
# routeName : 호남고속도로
# rdf-schema#label : 꼬막돌솥비빔밥
# direction : 논산
# ========================
# salePrice : ￦7,000
# batchMenu : 해물된장찌개
# serviceAreaName : 옥천
# routeName : 경부고속도로
# rdf-schema#label : 해물된장찌개
# direction : 부산
# ========================
# salePrice : ￦7,000
# batchMenu : 단양마늘 약초 갈비탕
# serviceAreaName : 단양
# routeName : 중앙고속도로
# rdf-schema#label : 단양마늘 약초 갈비탕
# direction : 부산
# ========================
# salePrice : ￦6,000
# batchMenu : 해물순두부찌게
# serviceAreaName : 벌곡
# routeName : 호남고속도로지선
# rdf-schema#label : 해물순두부찌게
# direction : 대전
# ========================
# salePrice : ￦7,000
# batchMenu : 정통수제 마늘돈가스
# serviceAreaName : 양산
# routeName : 경부고속도로
# rdf-schema#label : 정통수제 마늘돈가스
# direction : 서울
# ========================
# salePrice : ￦7,000
# batchMenu : 매실 제육덮밥
# serviceAreaName : 이천
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 매실 제육덮밥
# direction : 통영
# ========================
# salePrice : ￦22,000
# batchMenu : 횡성한우스테이크
# serviceAreaName : 횡성
# routeName : 영동고속도로
# rdf-schema#label : 횡성한우스테이크
# direction : 인천
# ========================
# salePrice : ￦7,000
# batchMenu : 해물영양솥밥
# serviceAreaName : 문경
# routeName : 중부내륙고속도로
# rdf-schema#label : 해물영양솥밥
# direction : 마산
# ========================
# salePrice : ￦6,000
# batchMenu : 엄나무닭개장
# serviceAreaName : 오창
# routeName : 통영대전ㆍ중부고속도로
# rdf-schema#label : 엄나무닭개장
# direction : 통영
# ========================
# salePrice : ￦7,500
# batchMenu : 수제왕돈가스
# serviceAreaName : 김천
# routeName : 경부고속도로
# rdf-schema#label : 수제왕돈가스
# direction : 부산
# ========================
# salePrice : ￦7,000
# batchMenu : 쇠고기 돌솥비빔밥
# serviceAreaName : 치악
# routeName : 중앙고속도로
# rdf-schema#label : 쇠고기 돌솥비빔밥
# direction : 춘천
# ========================
# salePrice : ￦6,000
# batchMenu : 베이컨 김치 볶음밥
# serviceAreaName : 공주
# routeName : 당진영덕고속도로
# rdf-schema#label : 베이컨 김치 볶음밥
# direction : 청원
# ========================

# %% [markdown]
# pd.read_html(url): url로 지정한 웹 페이지에서 테이블<table>을 전체를 읽어서 데이터 프레임으로 변환

# %%
#pip install html5lib
import pandas as pd
url = 'ww.html'
a = pd.read_html(url)[0]
a
# Out:
#      A    B    C
# 0  aaa  bbb  ccc
# 1  qqq  www  ggg

# %%
b = pd.read_html(url)[1]
b
# Out:
#      D    E    F
# 0  ddd  eee  fff

# %%
c = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download')[0]
c
# Out:
#            회사명    종목코드               업종  \
# 0           DL     210           기타 금융업
# 1        DRB동일    4840         고무제품 제조업
# 2          DSR  155660      1차 비철금속 제조업
# 3           GS   78930           기타 금융업
# 4        GS글로벌    1250        상품 종합 도매업
# ...        ...     ...              ...
# 2483    토마토시스템  393210   소프트웨어 개발 및 공급업
# 2484        틸론  217880   소프트웨어 개발 및 공급업
# 2485  플럼라인생명과학  222670  자연과학 및 공학 연구개발업
# 2486  한국미라클피플사  331660      기타 화학제품 제조업
# 2487       휴벡셀  212310       의료용 기기 제조업
#
#                                                    주요제품         상장일  결산월  \
# 0                                                  지주회사  1976-02-02  12월
# 1                     고무벨트(V벨트,콘베이어벨트,평벨트),프라스틱제품 제조,판매  1976-05-21  12월
# 2                                                합섬섬유로프  2013-05-15  12월
# 3                                           지주회사/부동산 임대  2004-08-05  12월
# 4     수출입업(시멘트,철강금속,전기전자,섬유,기계화학),상품중개,광업,채석업/하수처리 서...  1976-06-26  12월
# ...                                                 ...         ...  ...
# 2483                                              UI솔루션  2021-10-14  12월
# 2484                    Cloud Solution (D,A,E,Rstation)  2015-05-28  12월
# 2485                                   강아지암치료제,돼지DNA테라피  2015-07-28  12월
# 2486                                     은나노스텝, 닥터오렌지 등  2019-10-28  12월
# 2487                                         척추용 임플란트 등  2016-07-26  12월
#
#                     대표자명                            홈페이지     지역
# 0                    전병욱     http://www.dlholdings.co.kr  서울특별시
# 1                    류영식             http://drbworld.com  부산광역시
# 2                    홍석빈              http://www.dsr.com  부산광역시
# 3     허태수, 홍순기 (각자 대표이사)                             NaN  서울특별시
# 4                    김태형          http://www.gsgcorp.com  서울특별시
# ...                  ...                             ...    ...
# 2483                 이상돈  http://www.tomatosystem.co.kr/  서울특별시
# 2484                 최백준          http://www.tilon.co.kr  서울특별시
# 2485              김앤토니경태           http://www.plsdna.com  서울특별시
# 2486                 이호경           http://www.kmpc.co.kr    경기도
# 2487      박정민, 허성규(각자대표)              http://huvexel.com    경기도
#
# [2488 rows x 9 columns]

# %%
#pip install lxml
import pandas as pd

def get_code(name):
    a = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download', index_col='회사명')[0]
    code = a.loc[name, '종목코드']
    code = '{:0=6d}'.format(code)
    return code

# %%
code=get_code('효성')
code
# Out:
# '004800'

# %%
import requests
import pandas as pd
url = 'https://finance.naver.com/item/sise_day.nhn?code=004800'

html = requests.get(url, headers={'User-agent': 'Mozilla/5.0'}).text
a = pd.read_html(html)[0]
a = a.dropna()#NAN 줄 제거
a
# Out:
#             날짜       종가     전일비       시가       고가       저가      거래량
# 1   2022.01.28  81400.0  2300.0  79100.0  81800.0  77500.0  76304.0
# 2   2022.01.27  79100.0  2400.0  82100.0  82700.0  78500.0  87317.0
# 3   2022.01.26  81500.0   900.0  81600.0  83000.0  81500.0  46851.0
# 4   2022.01.25  82400.0  2400.0  84600.0  85200.0  81400.0  72817.0
# 5   2022.01.24  84800.0  2700.0  86000.0  86900.0  83700.0  81145.0
# 9   2022.01.21  87500.0   500.0  87100.0  87900.0  87000.0  38824.0
# 10  2022.01.20  88000.0  1100.0  87300.0  88300.0  86800.0  26822.0
# 11  2022.01.19  86900.0   400.0  86400.0  88100.0  85500.0  44046.0
# 12  2022.01.18  87300.0  2600.0  89900.0  90400.0  87100.0  56864.0
# 13  2022.01.17  89900.0   800.0  90200.0  91100.0  89600.0  30811.0

# %%
import matplotlib.pyplot as plt

plt.plot(a['날짜'], a['종가'])
plt.plot(a['날짜'], a['시가'])
plt.title('hyosung')
plt.xlabel('date')
plt.ylabel('won')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import tkinter as tk

x=np.arange(1, 10, 1)
y=2*x**2
fig = Figure(figsize=(10, 7), dpi=100)  #그리프 그릴 창 생성
fig.add_subplot(1,1,1).plot(x, y)#창에 그래프 하나 추가

window = tk.Tk()  #Tk 객체 생성. 기본 윈도우 객체
canvas = FigureCanvasTkAgg(fig, master=window)
canvas.draw()
canvas.get_tk_widget().pack()
window.mainloop()

# %%
data = pd.read_excel('영화순위.xlsx', engine='openpyxl')
data
# Out:
#       순위                  영화명        개봉일  예매점유율       예매매출액         누적매출액  \
# 0      1           해적: 도깨비 깃발 2022-01-26  0.397   753114740    1422030120
# 1      2                 킹메이커 2022-01-26  0.209   393301560     745621710
# 2      3        스파이더맨: 노 웨이 홈 2021-12-15  0.064   106135980   72426052500
# 3      4                    듄 2021-10-20  0.058   185549000   16903293110
# 4      5  극장판 안녕 자두야: 제주도의 비밀 2022-01-27  0.043    71087090      53936070
# ..   ...                  ...        ...    ...         ...           ...
# 157  148            꾼들의 삽입 법칙        NaT  0.000        5000             0
# 158  148                   원샷 2022-01-10  0.000        5000       6950000
# 159  148            연주의 섹스파트너        NaT  0.000        5000             0
# 160  148  사울 레이터: 인 노 그레이트 허리 2021-12-29  0.000        5000      14332500
# 161   합계                  NaN        NaT    NaN  1995413960  249988727550
#
#       예매관객수     누적관객수
# 0     76207    167629
# 1     40085     90035
# 2     12240   7231335
# 3     11122   1549346
# 4      8196      6537
# ..      ...       ...
# 157       1         0
# 158       1      6501
# 159       1         0
# 160       1      1600
# 161  191781  29112160
#
# [162 rows x 8 columns]

# %%
from selenium import webdriver
import time

chromedriver = 'C:\\Users\\Playdata\\Desktop\\pythonProject2022_01\\jupyter_src\\chromedriver_win32(2)\\chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://www.kobis.or.kr/kobis/business/stat/boxs/findRealTicketList.do')
driver.find_element_by_xpath('//*[@id="searchForm"]/div/div[4]/button[1]').click()
time.sleep(3)
tbl = driver.find_element_by_css_selector('#content > div.rst_sch > table')
tbody = tbl.find_element_by_tag_name("tbody")
rows = tbody.find_elements_by_tag_name("tr")
for index, value in enumerate(rows):
    tds=value.find_elements_by_tag_name("td")
    print(tds[0].text+'.'+tds[1].text)
# Out:
# <ipython-input-16-f9df54774083>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)
# <ipython-input-16-f9df54774083>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="searchForm"]/div/div[4]/button[1]').click()
# <ipython-input-16-f9df54774083>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tbl = driver.find_element_by_css_selector('#content > div.rst_sch > table')
# 1.해적: 도깨비 깃발
# 2.듄
# 3.나일 강의 죽음
# 4.극장판 주술회전 0
# 5.해리 포터와 불사조 기사단
# 6.킹메이커
# 7.덩케르크
# 8.스파이더맨: 노 웨이 홈
# 9.씽2게더
# 10.355
# 11.극장판 안녕 자두야: 제주도의 비밀
# 12.하우스 오브 구찌
# 13.비틀즈 겟 백: 루프탑 콘서트
# 14.만년이 지나도 변하지 않는 게 있어
# 15.어나더 라운드
# 16.드라이브 마이 카
# 17.태일이
# 18.캐롤
# 19.타오르는 여인의 초상
# 20.나의 촛불
# 21.킹스맨: 퍼스트 에이전트
# 22.굿 보스
# 23.웨스트 사이드 스토리
# 24.데드락: 라스트 리벤지
# 25.미싱타는 여자들
# 26.프리! 더 파이널 스트로크 전편
# 27.특송
# 28.가슴이 떨리는 건 너 때문
# 29.펀치 드렁크 러브
# 30.피그
# 31.인어가 잠든 집
# 31.원 세컨드
# 33.리코리쉬 피자
# 34.경관의 피
# 35.프랑스
# 36.장민호 드라마 최종회
# 37.도쿄 리벤저스
# 38.특수본
# 38.옆집 부부와 구멍 깐부
# 40.파이어 셧 업 인 마이 본즈
# 41.블러드써스티
# 42.섹스웨더
# 43.프렌치 디스패치
# 44.더 마더
# 44.극장판 천재 추리 탐정 셜록홈즈
# 46.밀라노 두오모 콘서트
# 47.틱, 틱... 붐!
# 48.임신한 나무와 도깨비
# 49.창극 변강쇠 점 찍고 옹녀
# 50.러브레터
# 51.바이올렛 에버가든 오케스트라 콘서트 2021
# 52.불한당: 나쁜 놈들의 세상
# 53.나쁜 교육
# 53.브로큰 임브레이스
# 55.레전더리 콘서트: 레너드 번스타인
# 55.귀향
# 57.걸 위드 더 카메라
# 58.청춘적니
# 59.피닉스
# 60.그을린 사랑
# 61.듣보인간의 생존신고
# 61.성덕
# 63.해탄적일천
# 64.퍼스트 카우
# 65.오오극장 개관 7주년 특별전 - 대구독립단편신작
# 66.비브르 사 비
# 67.스파이의 아내
# 67.공포분자
# 67.시카리오: 나이트 오브 이스케이프
# 67.위기의 여자 하숙생
# 67.퇴폐의 온상 은밀한 만남
# 67.스릴 넘치는 그녀의 비밀 섹스
# 67.그녀의 육체 앞에 무너진 이성
# 67.짐승남의 거친 사냥법
# 67.속살 보여준 누나
# 76.클리포드 더 빅 레드 독
# 76.크리미널 카운트다운
# 78.그녀에게
# 78.너에게 가는 길
# 78.볼프스부르크
# 78.바바라
# 82.존경하고 사랑하는 국민여러분
# 83.거래완료
# 83.짬뽕비권
# 85.옐라
# 86.윤희에게
# 87.하나 그리고 둘
# 87.운디네
# 87.내가 속한 나라
# 87.좀비 살아있다
# 91.흐르다
# 91.트랜짓
# 91.특수부대 코만도
# 91.투모로우 아포칼립스
# 95.샌 안드레스 메가 대지진
# 96.블루버스데이
# 96.1975 킬링필드, 푸난
# 96.레이징 파이어
# 99.연인
# 99.아웃브레이크 호텔
# 101.커피와 담배
# 101.타이페이 스토리
# 101.효자
# 101.오렌지필름 7주년, mixtape vol.7 (오렌지필름기획전)
# 105.패터슨
# 106.해피 아워
# 106.열망
# 108.트로트는 인생이다
# 108.전장의 피아니스트
# 108.마담 프루스트의 비밀정원
# 108.램
# 108.오직 사랑하는 이들만이 살아남는다
# 108.벗어날 탈 脫
# 108.미스터 앤 미세스 아델만
# 108.물오른 하숙집
# 116.천국보다 낯선
# 116.사울 레이터: 인 노 그레이트 허리
# 118.파리로 가는 길
# 118.러브 인 프로방스
# 118.러브 어페어: 우리가 말하는 것, 우리가 하는 것
# 118.영원한 휴가
# 118.끝없음에 관하여
# 118.남과 여: 여전히 찬란한
# 118.고양이를 부탁해
# 118.티탄
# 118.노웨어 스페셜
# 118.더 파더
# 118.소설가 구보의 하루
# 118.수호지-최강무적 탕륭
# 118.셀러브리티 섹스테이프
# 118.퍼시픽 모비딕
# 118.대호출격
# 118.연변 아가씨의 맛섹사 - 감독판
# 118.야한 정사의 맛-감독판
# 118.영원한 제국
# 136.꽃다발 같은 사랑을 했다
# 136.아이 스틸 빌리브
# 136.5일의 마중
# 136.그리고 삶은 계속된다
# 136.보는 것을 사랑한다
# 136.타부 : 잘못된 관계
# 136.화끈한 새엄마:온천여행
# 136.세 여자의 질펀한 서비스
# 136.새엄마의 속살
# 136.비올레타
# 136.음란간호:끈적이는 손장난
# 136.내 아내의 언니 5
# 136.모텔방에서 사는 여자
# 136.닌자: 킬 사무라이
