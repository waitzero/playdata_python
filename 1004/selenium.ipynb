# %%
import numpy as np
import pandas as pd

# %%
#pip install selenium

# %%
from selenium import webdriver
import time

#웹 드라이버 경로
chromedriver = 'C:\\Users\\Playdata\\Desktop\\pythonProject2022_01\\jupyter_src\\chromedriver_win32(2)\\chromedriver.exe'
#웹 드라이버 실행
driver = webdriver.Chrome(chromedriver)

# 웹 페이지 이동
driver.get('https://www.kobis.or.kr/kobis/business/stat/boxs/findRealTicketList.do')

# 원하는 요소 검색
driver.find_element_by_xpath('//*[@id="searchForm"]/div/div[4]/button[1]').click()

#처리끝날때까지 기다림
time.sleep(3)

tbl = driver.find_element_by_css_selector('#content > div.rst_sch > table')
tbody = tbl.find_element_by_tag_name("tbody")
rows = tbody.find_elements_by_tag_name("tr")# 테이블에서 줄 추출
for index, value in enumerate(rows):
    tds=value.find_elements_by_tag_name("td")
    print(tds[0].text+'.'+tds[1].text)
# Out:
# <ipython-input-6-bcab15443b02>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)
# <ipython-input-6-bcab15443b02>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="searchForm"]/div/div[4]/button[1]').click()
# <ipython-input-6-bcab15443b02>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tbl = driver.find_element_by_css_selector('#content > div.rst_sch > table')
# c:\users\playdata\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webelement.py:341: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# c:\users\playdata\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webelement.py:359: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# 1.극장판 주술회전 0
# 2.나일 강의 죽음
# 3.듄
# 4.해리 포터와 불사조 기사단
# 5.해적: 도깨비 깃발
# 6.덩케르크
# 7.355
# 8.나의 촛불
# 9.굿 보스
# 10.만년이 지나도 변하지 않는 게 있어
# 11.킹메이커
# 12.비틀즈 겟 백: 루프탑 콘서트
# 13.스파이더맨: 노 웨이 홈
# 14.하우스 오브 구찌
# 15.어나더 라운드
# 16.씽2게더
# 17.태일이
# 18.드라이브 마이 카
# 19.리코리쉬 피자
# 20.가슴이 떨리는 건 너 때문
# 21.극장판 안녕 자두야: 제주도의 비밀
# 22.캐롤
# 23.타오르는 여인의 초상
# 24.프리! 더 파이널 스트로크 전편
# 25.더 마더
# 26.늦봄2020
# 27.데드락: 라스트 리벤지
# 28.킹스맨: 퍼스트 에이전트
# 29.미싱타는 여자들
# 30.웨스트 사이드 스토리
# 31.메기
# 32.특수본
# 33.특송
# 34.섹스웨더
# 35.온 세상이 하얗다
# 36.파이어 셧 업 인 마이 본즈
# 37.원 세컨드
# 38.밀라노 두오모 콘서트
# 39.인어가 잠든 집
# 40.나쁜 교육
# 40.펀치 드렁크 러브
# 40.애니멀 체인지
# 43.도쿄 리벤저스
# 44.임신한 나무와 도깨비
# 44.프랑스
# 46.창극 변강쇠 점 찍고 옹녀
# 47.브로큰 임브레이스
# 48.귀향
# 48.블러드써스티
# 50.극장판 천재 추리 탐정 셜록홈즈
# 51.피그
# 52.경관의 피
# 53.틱, 틱... 붐!
# 53.듣보인간의 생존신고
# 55.성덕
# 56.러브레터
# 57.청춘적니
# 58.오오극장 개관 7주년 특별전 - 대구독립단편신작
# 59.프렌치 디스패치
# 59.그을린 사랑
# 61.레전더리 콘서트: 레너드 번스타인
# 61.너에게 가는 길
# 61.볼프스부르크
# 64.그녀의 육체 앞에 무너진 이성
# 64.위기의 여자 하숙생
# 64.짐승남의 거친 사냥법
# 64.속살 보여준 누나
# 64.퇴폐의 온상 은밀한 만남
# 64.스릴 넘치는 그녀의 비밀 섹스
# 70.바바라
# 70.피닉스
# 72.천국보다 낯선
# 72.거래완료
# 72.불한당: 나쁜 놈들의 세상
# 75.윤희에게
# 75.크리미널 카운트다운
# 77.비브르 사 비
# 77.패터슨
# 77.흐르다
# 80.해탄적일천
# 81.장민호 드라마 최종회
# 81.하나 그리고 둘
# 83.바이올렛 에버가든 오케스트라 콘서트 2021
# 83.오직 사랑하는 이들만이 살아남는다
# 85.역으로 가는 길을 알려줘
# 85.옐라
# 87.연인
# 87.퍼스트 카우
# 87.남과 여: 여전히 찬란한
# 87.걸 위드 더 카메라
# 87.오렌지필름 7주년, mixtape vol.7 (오렌지필름기획전)
# 87.아웃브레이크 호텔
# 87.투모로우 아포칼립스
# 94.그녀에게
# 94.끝없음에 관하여
# 94.운디네
# 94.특수부대 코만도
# 98.커피와 담배
# 98.공포분자
# 98.벗어날 탈 脫
# 98.더 파더
# 98.레이징 파이어
# 98.좀비 살아있다
# 104.타이페이 스토리
# 104.미스터 앤 미세스 아델만
# 104.더도 말고 덜도 말고
# 104.삼국지 관운장: 청룡언월도
# 108.마담 프루스트의 비밀정원
# 108.1975 킬링필드, 푸난
# 108.물오른 하숙집
# 108.수지
# 108.샌 안드레스 메가 대지진
# 113.영원한 휴가
# 113.열망
# 113.내가 속한 나라
# 116.러브 어페어: 우리가 말하는 것, 우리가 하는 것
# 116.파리로 가는 길
# 116.러브 인 프로방스
# 116.블루버스데이
# 116.클리포드 더 빅 레드 독
# 116.비올레타
# 116.메소드연기
# 116.벌지 탱크 대전투
# 116.퍼시픽 모비딕
# 116.연변 아가씨의 맛섹사 - 감독판
# 116.대호출격
# 116.영원한 제국
# 116.수호지-최강무적 탕륭
# 116.셀러브리티 섹스테이프
# 116.야한 정사의 맛-감독판
# 131.십계
# 131.당신얼굴 앞에서
# 131.고양이를 부탁해
# 131.올리브나무사이로
# 131.소설가 구보의 하루
# 131.발정난 간호사
# 131.욕정 끝 쾌락시작
# 131.잊혀질 남편의 맛
# 131.새엄마 발키리 무삭제판
# 131.중년 부인의 양기파티
# 131.넣으러 가는 길
# 131.타부 : 잘못된 관계
# 131.트로트는 인생이다
# 131.존경하고 사랑하는 국민여러분
# 131.트랜짓
# 131.닌자: 킬 사무라이

# %% [markdown]
# <요소 추출함수>
# - DOM 내부에 있는 여러개의 요소들 중에서 처음 찾아지는 요소를 추출하는 메소드
# find_element_by_id(id) # id 속성으로 요소를 하나 추출한다.
# find_element_by_name(name) # name속성으로 요소를 하나 추출한다.
# find_element_by_css_selector(query) # CSS 선택자로 요소를 하나 추출한다.
# find_element_by_xpath(query) # XPath를 지정해 요소를 하나 추출한다.
# find_element_by_tag_name(name) # 태그 이름이 name에 해당하는 요소를 하나 추출한다.
# find_element_by_link_text(text) # 링크 텍스트로 요소를 하나 추출한다.
# find_element_by_partial_link_text(text) # 링크의 자식요소에 포함돼 있는 텍스트로 요소를 하나 추출한다.
# find_element_by_class_name(name) # 클래스 이름이 name에 해당하는 요소를 하나 추출한다.
#
# - DOM 내부에 있는 여러개의 요소들을 모두 추출하는 메소드
# find_elements_by_css_selector(query)
# find_elements_by_xpath(query)
# find_elements_by_tag_name(name)
# find_elements_by_class_name(name)
# find_elements_by_partial_link_text(text)
#
# <기능 함수>
# clear() # 글자를 입력할 수 있는 요소의 글자를 지운다.
# click() # 요소를 클릭한다.
# get_attribute(name) # 요소의 속성 중에 name에 해당되는 속성의 값을 추출한다.
# is_displayed() # 요소가 화면에 출력되는지 확인한다.
# is_enabled() # 요소가 활성화 되었는지 확인한다.
# is_selected() # 체크박스 등의 요소가 선택 상태인지 확인한다.
# screenshot(filename) # 화면을 캡처해서 filename으로 저장한다.
# send_keys(value) # 키를 입력한다. 일반적으로 text 데이터를 보낸다.
# submit() # 입력 양식을 전송한다.
# value_of_css_property(name) # name에 해당하는 CSS 속성 값을 추출한다.
#
# <네이버 로그인 페이지>
# https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com

# %%
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys 
import time 
#import pyperclip

chromedriver = 'C:\\Users\\Playdata\\Desktop\\pythonProject2022_01\\jupyter_src\\chromedriver_win32(2)\\chromedriver.exe'
driver = webdriver.Chrome(chromedriver) 

url = 'https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com' 
uid = '네이버아이디' 
upw = '네이버패스워드' 

driver.get(url) 
time.sleep(2) 

tag_id = driver.find_element_by_name('id') 
tag_pw = driver.find_element_by_name('pw') 

tag_id.send_keys(uid)
tag_pw.send_keys(upw) 
time.sleep(1) 

login_btn = driver.find_element_by_id('log.login') 
login_btn.click() 
time.sleep(2)
# Out:
# <ipython-input-10-100a5ad38aa8>:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)
# <ipython-input-10-100a5ad38aa8>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tag_id = driver.find_element_by_name('id')
# <ipython-input-10-100a5ad38aa8>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tag_pw = driver.find_element_by_name('pw')
# <ipython-input-10-100a5ad38aa8>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   login_btn = driver.find_element_by_id('log.login')
